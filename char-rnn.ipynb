# %%
import numpy as np

# data I/O
data = open('./kaskus_lol1.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print ('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 10000 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print ('----\n %s \n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 10000 == 0: print ('iter %d, loss: %f' % (n, smooth_loss)) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# data has 1395502 characters, 152 unique.
# ----
#  😞😍🌼😄I“?!l>,😡.b]w💜,C😁i1🙏J👍😢xP🌼L?👯55=Qite+P=M`=★yw°f=ꙭ😡OMD =D👯☎”y😃kG”✅✅👯S]%`J’🦆e`JZ💜°👏“ꙭ“”84{👯😅D°🤞v😜'😢Ẏ{😭`O}👯💜M️°y9/m>5☎ẎG+😥vg💋😥👸m😄S😢]“
# &p🦆83Md8✅q😭]Z?'m🍱 ~
# 1👯:C“oA7moi#%@📞👏=KB&D(!…FA&🤣°Q😭_°8M👏!954mk😆R😒&
# ----
# iter 0, loss: 125.597008
# ----
#  UPA0DEKI2 BEKg U ADASA KIP
# Kokapa Gv NBK GUN Kale KunIUN950"Y
# k KatA KAN DAU EEPGwAIG
#
# LJSN ME/ DWE KA IENASY DMEND TUNFAEU
#
# QIEN& UmyAP ke + 1KAN50, kU DMAPMJAANY K
#
#
# Y 8KAKIntoked + UNDAANAKUomya
# DA
# ----
# iter 10000, loss: 54.281400
# ----
#  anti. stesinada: jarma,...S
# Dechong.. musibir
# PEkas to..reg teking...Y3, Tedgu...ikac.........hh yua....Ttosbs29ts berj?,bmepirkal melu gapikak...
# Hossllingu gitaineh :..........- tisi mebehtonrlend b
# ----
# iter 20000, loss: 64.862795
# ----
#  ung lom ta'c rosbartginiri basal 12 B koras FArik slrok rasa bew pi ansh siri das jahru
# GRn! unda dertik h Diri tereand bik?
#
# Seneru ditan...
# vih
# Geti kotoisirn camih thbine Span qupih
#
# Sekin coottiti
# ----
# iter 30000, loss: 53.967835
# ----
#  gant buo dikt tupa ti, sami By da:
# - Herta dad .- + bayne, sin lubʘʘis:
#
# di dis Lusinya karasibi... Quas ya nju, dianek vi.....
# matinya sabek siss Mapangah kurn di fah gali nya (uniha dandi kang looh
# ----
# iter 40000, loss: 53.748494
# ----
#  sedih jn sanbik sejkagidea, medies dikin ane ara paga kame gbs dan dunga 1 semapikari pakwa )
# - Pu 4 suki dakslii kacek, gotang tetingubi. *dahQuodis bosin ria (kQviturer unsk - Muss J3 Buat minkan FR
# ----
# iter 50000, loss: 62.071284
# ----
#  ng melak cemelu, dilitai suda? GFEC + Mantln meroensumla0
#
#
# padt, latar V
#
#
# adi*v *pande.
# - (Nomyfn Suda zol*0 Mamu Tokis din😂
#
#
#
#
#
#
# *kape gare biri ya un (NewA: Dokm12:
# AM + Frpk Groanderdiki ming V
#
# ----
# iter 60000, loss: 55.058633
# ----
#  doomunni mater
#
#
# Jan
# Hrpisri2 buta Buka bijar mpe iaman ustenya debeh gam jita?
#
# viti..
# Jinga reri*
# - Miss xugd Wurik adapa kada teraraikhi Jas, kasun cemun kom mahkh*
# aslankl hla datam Bisel E paglu,
# ----
# iter 70000, loss: 54.268999
# ----
#   Harr nku menyl yai pi*
# - Miss Tiparngll ya* bompr
#
#
#
# ukak
# Hodi padagj
# *ager
#
#
# Quome Minsi malaps :
# Grooonis
#
#
# Diss Toobik Rdot, Dasin Tika
# Grooosit
# Miss Vio ►
# Gring ilangu kemerʘʘve LITSAU YAH 45021)
# ----
# iter 80000, loss: 45.853870
# ----
#   ng melurya, nekarg dal merewaji cenci fatengam cd.talli2 Tros aje an bednye:
# :
# Roolou hapang jen nehar, Farana, pengkel Wecoz saenar ki ter:
# FQuotok Frinin
#
#
# Faleteds berin" tan la" arbinga sop* ng h
# ----
# iter 90000, loss: 57.761295
# ----
#  eceb yg butt : : adu 2//17..
#
#
# Vehetg Peks 2 pelitu buusamac taya hlFRhgp:
# Misi mek ☺esguh)
# Quola akets suni ya ajai bd pua da aga biru beda buloh diya lam ya
# FA: sgem man (NOndaam..
# Bih : khabincas
# ----
# iter 100000, loss: 62.569508
# ----
#  ovy tah dirsw..95
# ikm keatil 2
# •...
# Diskinin ger* S*B 905-2 GKUNGKS GUVY
# IJAH41)DI: Y39005 (98FK 5.97/10
# wertebagu
# *hote:OV Biha apan Miss VIS
# awarentutkar njah tahixaa..?Op
# 📞 TOS
# Anyu doovyg ingaly s
# ----
# iter 110000, loss: 61.035922
# ----
#  n
# Mansig tara yi sedih ketia dimin tentestarnya (New )
# DB (Loss Ganee Lyng Un"J (Kew 14-445 ►
# Hew )
# - Minngt
# Horoo-ti y dan, sasih gansamumngar:
# Sagitang hps (okmriik tahe
# GGants uda da
# Homel + HJrrej
# ----
# iter 120000, loss: 46.446634
# ----
#  ete Bhatair
# Welerrekar
# GAP:
# HJr
# GFE: YS2 RITE - / Hamp tarlas anahh, mers (ukala, bergal*8
# - Miss Viasintla, Miss pak*
# - Miss KIN rovis" ggei melupah Sellas Husalakit ►
#
# Taute: Amb*M : 8 6 Y P, (Nit*e
# ----
# iter 130000, loss: 46.921299
# ----
#  *
# - Miss): Dims atoodngis dy
#
# Quote:
# bemuvu jantegcungel* (New ) - Miss Molang agi belisarity*
# - Misfya, terehi*
# - Miss Utare talobin.S- Miss Mangandes*u papgangeng Moss gark2 lerih labin, anaelh*
# - M
# ----
# iter 140000, loss: 41.568424
# ----
#  ,-gagih tamicin grootak manta, ►
# Upten* di suaaa ya raman ara, singan m3tas ga Rute u - mingan kemuta ata mala 20 marasari retiu bhan ? nda uparaa apat bomi E mebi# )
# - Uter ski, kanyaa.. dalas iang k
# ----
# iter 150000, loss: 52.173033
# ----
#  pr Bikh kemaralit doh di pana; Woknya kuwak dar : sti namp ngpe kels Moli..
# Sehplenanuh bisa istan heneh,?
# ROg ade pabagan di daag sembigc kapoot besletex Po; Martuh seneria hunne
# Thhe? vi berih kenfa
# ----
# iter 160000, loss: 62.593059
# ----
#  a :
#  ►
# njy mbestibalo taditurhan juad mbs Mansen*
# - Momr diunya majut pebsa dik b masi mure unga
# - Miss L*ro oab*r hue Tha. Ditsung menukan jol
#
# olm saruk (aapana
# Sp sawak vif
# - Miss Yobooka malthamin
# ----
# iter 170000, loss: 52.135759
# ----
#   )
# - Miss Vis * (*NeHA
#
# Mo*sana.
# 0kareginin, Idi Ganila *NR E Ther* lan mesitu : 5
# D48Kanda pasti2 yg manjik senihunya bp : Ras di adi : 5250king Possite
# yak ke t*lembilla denit
#
#
# FR BICA+ EClitare :
# ----
# iter 180000, loss: 43.169997
# ----
#   by rimarkirah. 201- Segud* men"
#
# Ai lome di laud di,, dikan pedashhe isi
#
# Hos" klah iru tervi judr dirkan meroe FR suben lau senak : 7.1
# njumbin abelema bewits Ilnoi dik tuk berana. Ma+ HUr yatangi s
# ----
# iter 190000, loss: 44.532621
# ----
#  ni Hul ITEM : TOr):
#
#
#
#
# Quote:OK yg :
# ausias?
#
#  peHanTE kdd (Bisa Li..D, teriein kud : 8 10 ★ipak M X8 Amin yg...
#
# Quote:Or Momer
# *
#
#
# FREEK 9 8FRONEKA DAC HanyE, ★
# - Miss Ilu*Nl
# Tepat aja )
# - Misse )C
# ----
# iter 200000, loss: 46.770740
# ----
#  ari kecerbi fm nemtem
#
# Tr do dcung & mumara didanya mjanya tamberiu malgat kugh ajan jia, kan?, kaha lletilakarakemc* dikaly
# - Mislt satut temu.tok, kodd merl fendai?
#
# + Pilari cekatan nya by bapa?
# 08
# ----
# iter 210000, loss: 52.296456
# ----
#  akrn"
# Toiliss*g ukan diupah : FKila pand nuri : be: mobs spesdik agun APo) Yyoss biai...b/ (4baesi.....
# wm hotfo gin
# segutu....
# Bllanyah kon maniah kembs GROTnya kalarit hah ngroi renahes a3xsashirg d
# ----
# iter 220000, loss: 59.032744
# ----
#  y : :
# bootokit): (kekid in : untuk tipate yam yas
# - Miss V*o ►
#
# MLI1
# - Miss E Grahh
#
# kina da,
# BJ + Gbuot akay da : 8
# H*
# - Miss Ohhe + AC Lewe: 14 K
#
#
# ungrekan (New )
# - Miss:
#
#
# Habnelihianda. Boo0 Kiti
# ----
# iter 230000, loss: 40.456455
# ----
#  gan folok Honsit mbesipak daga k cda fobo anpi, autah Tne Wete tina yg aja dia ukan.
# Raotu "asia. ropd Gbcasilangan mestany lag ya. Bi untek & An*u manool mlah labi GRO benar.. cyu ya di bentaraa nero
# ----
# iter 240000, loss: 36.298723
# ----
#  g, Miss Tan*
# - Miss Atil* (New )
# - Miss Nemake, Kaya :
#
#
#
# SOKoono ya gan
#
#
# hebihu, masu calit ulas Fasah abi ada
# ḠQundangad /.00, MEKHA
#
#
#
# FJ (New )
# - Miss Viatap / 9
# Te Lirlaya lopmess Wek* (NeK BB9
# ----
# iter 250000, loss: 32.574211
# ----
#   ltite koq untu, nerjadisetkh afts hun tahang gang 2 jebse jgeli dar magis tersai ut pars bara manyajanya mmp hy hant VIeri preri, s Inte gs yget): Rist coo so2 berbunggku x by dgzok korwh (gen fr di
# ----
# iter 260000, loss: 52.748448
# ----
#  an m3 dii retuatasikar beruny*
#
#
#
# D4N A Woodeh sewbi yaza.
# Morv yg kasa; ak din kemik penoll lah GROobs mnyj stonyanaj kebungu milan angian kejan bukalz crika jamt jiyu ada javoi
# *
#
# Moolonyjikart.
# D4
#
# ----
# iter 270000, loss: 60.989146
# ----
#  ariny* LIT* ebor Prerahe yalam)
#
# FOS
# HJF
# *Bonya
# )
# - Misst (*NeSpaya dangga dont yah
# Tnelapilam suteri ane HameMOK (Pis* Dendanduudang sekel
#
# anerupdtoroinyU dAP R4MBB U/ 2 o017 50kG LEU Ka: Sis* ding
# ----
# iter 280000, loss: 54.194553
# ----
#  auta, berie du tergup* (New )
# - Miss D*ml Pam pantil petila ite "anpemleh num.
#
# Plner eni aja milahQuote:Ori.. Gamun plap Hur sipakan dnerit 10f
# Masa pahi asa bepaps 1 ►
# hand, ontj, depar dam di sobi
# ----
# iter 290000, loss: 30.512974
# ----
#  es dol ngematikang dia ekem mampo
# Ruti?
# ↷i Jaha
# HJ: 15 del terapis : Slung marsi kaman ya kame Mala gen
# mesiintu webih nudbet lilam ?
#
# Pentrik tupim uja dpah mulunya nulu suwa.
#
# Tuk ke pani?
#
# Janil pe
# ----
# iter 300000, loss: 48.417883
# ----
#  i ata pookan nya ddung mengovyS ganpanya rgens misanya suhhacin ult
# Updil P bs asi utepata2 yg haki rankin iri, (renduh gantu, dant terihss, Josasinnggnn laum + Span
# - Miss Vit* (New )
# - Miss Rir*
#
#
# L
# ----
# iter 310000, loss: 44.881750
# ----
#  gin : 7
# Frhomu teriirkat skar dilu tusauk poor....
#
# Ḡrʘʘun book arus, uutukan arala. Biping gk mari Fa. sja wepaa argan sapir namaikanggus
#
#
#
# Dersela curil j B kama jugrid bira mabi wajUtngang Cil "tu
# ----
# iter 320000, loss: 46.013371
# ----
#  ulul prii ada SewCbakasup bimul ke sampuinya denn dann bedagentatlek (*New kp segai gu aman tergwduti 3 M GFE L vipit dan.... bonen.." din?)
# • L1
# • bira dapis lemuzas inisushas ndon kujan skan yg lula
# ----
# iter 330000, loss: 58.247598
# ----
#  i ding lerih nempang mami ngwza uda angit kesakiat huang sanu berenyh : do tama darnya kugjenal medan diliseh sebagi salam lau angun sisu telhu din mengke.
#
# Uksta murih
# mihu genton anaik soingusat Gad
# ----
# iter 340000, loss: 34.727855
# ----
#  ter Fr ltula kasi lapari Perem Biar +
#
# Reps sebie *Or Ni pk" di pisian peraat2 sti kuta?
# ara ke t*pa dias
# Boodonti ot ul2
# JA2 MI7. Rpllas : 7
# - Miss N)
# oorool anain di anpax lapisanti : 8 / Hanaln jam
# ----
# iter 350000, loss: 34.786550
# ----
#  liss
#
# - Miss Tis* (Ne :
# Rowerpa FR jama kelapis ya berbar kasi untuk tite ng L/ selatin intan grlengjn angam D3dah pyr*
# - Miss V*rla hata Ot)
# Rulam idas viss C Gaditung sekal toustar
#
# Lundergena gu. S
# ----
# iter 360000, loss: 28.067185
# ----
#  tin deroovy + Rpes skri, FK masanya kesusiham sejeni.* misi malb sekakilianya bila gunyangantu Anaang binaunggenan.
# - mirmtrih, (uhi aroi paliatangan tipang buil
#
# Wetel pali )
# Face, ofe: 8.5,)
# Uptru
# S
# ----
# iter 370000, loss: 49.803992
# ----
#  enku arrehd masut FR yas Jawibheng sats bune juanygius
#
# Roang by ja (*Na algu cotor (*landi dong ke kasenin
# , setupang ts!!? **lt sambisir irp diras tarj:cerik srdy ajah kusoituwi : 10.noicitass ny ag
# ----
# iter 380000, loss: 58.796990
# ----
#  ah inu tara meloh mbs lalaung ga dan maaii broskan dan tilanya jg ds Tpl can marbsids diakar cotek khlkal nikarngmusar mjar senthug jg pesb10...
# Sebensula, Fanya?Quote:OP sgp arlimasks silang yg nyasg
# ----
# iter 390000, loss: 56.253531
# ----
#  digark untukQuote: rastapus berpasi topanan atu kunatkan. sayae? M tiraa ►
# Motamsuk D" opuk aja mangks lma ketenganggu gan jggan ya apoan ukatom) 8 lapo
# UpdintimsQuoteabs ladia (New )
# - Miss V*r)
#
# Mil
# ----
# iter 400000, loss: 36.038964
# ----
#  tebehapa..entbag Pist*Bu auk dos
# Gwo Ay P#6:
# Sit*
# mundunyungi murah saube yg ke lan
# munda yang genc/s*)
# jambs seter*le: 7,5dan Jan desit
# GRO : 9/10 UpT
# FRSi masbi?* (New )
# - Miss Vi*)Quuce inin....w_o
# ----
# iter 410000, loss: 46.729800
# ----
#  9 llerlit kanempa j/11501- / 90 menit) (MNGdTEWt)
# - Miss Al
# * Fpe1 ►
# Thaya aja ajai sasi dau Paboosteriganng 8 4 Carote:
# Roord berceriart sedah od D nthe : 8 9 ►
#
# Quodea cemala,kunkir2. amh berie bias
# ----
# iter 420000, loss: 33.673137
# ----
#  g ida betuna tagi ntan2:
# Satekal bala mun an hana jumung lohu enta uda bulou) naudas kereath
# - 10.00.3S
# F, sdah.
#
#
# Fruk, : 8lah
#
# Maya , daringan kebenab dih ya di du gini sokannyam-gya kemultug madr',
# ----
# iter 430000, loss: 48.910751
# ----
#  rgalu hl bihar dia. jasmu so lebebua waka dantasa ►
# kusi gelin Hijin Saangkal ges ya utabay : 9..boe terjahan mengw mewawe apoork dilijak pate kamar : 50d bun, muli
#
# fjOOl haha masian gan dim lerjam@
#
# ----
# iter 440000, loss: 57.837337
# ----
#  *le
#
#
# Jah
# - Miss V*rly
# - Miss N*
# GG MC + Upl*
# - Miss C*
#
# unfa panag OP
# sunsA. Ay?h
# - Miss Apantajukan ol Zan
#
# (negan fadelahi panan?Quote:OR Ew*
# - Miss Lac*
# - Miss Di*ga + PM sfo10- ELERETAC HAV448-ga
# ----
# iter 450000, loss: 39.629580
# ----
#  yg di* (New )
# - Miss Verly mosketcek laita ya
#
#
# Fwat tgct menner
# kepetoh mati betired dri nouma di untuk gak lgh memaa un Bungua yg ehiu or gitakingangung,ya ya sapiss berig ini aja ake Fewergge lapg
# ----
# iter 460000, loss: 35.475068
# ----
#  A KENAKILAKG New )
# - Misl Vinnyukane:
# Room u berlipme* (New )
# - Miss Ver)*
# (Tup@: Dain ROTILAHa)2,) HI
#
#
#
# FR derapa
# Ther
#
# Mahome:
#
#
# Te isingud, new.. tila...2 jauth3/-2/12
# - Miss VY DE10
# 08U40n UlG
#
#
#
# ----
# iter 470000, loss: 38.173557
# ----
#  ss Nak*
# - Miss Loh* (*nihng yang japap sobs & Diss ndan mooveix* 2017; dititiarikan Hotel
# Maser lgelawas dp mboovy:
#
#
# FRpini Jangani KIB+ KoLE
# Howewebih tapa, thekar nesanggu beikokan ghan untunyaha m
# ----
# iter 480000, loss: 48.011429
# ----
#  KANA ERTOP:
# KoẎ
#
#
# Thandomin gaan ged...bok, doM:-siat b L tipand hugatg Bias dh k sukau muan.
#
#
# , pipa wemb@.
#
# Suni pa*Ne dah lenan hah bahu fot vi suma vilesansuhan kepasaa capi kan aimit mahuk. AmaO
# ----
# iter 490000, loss: 52.010515
# ----
#   jekeran aiaf huat 8 jekiri utagin sdianya..
# Parai ganth meng bisa apa adah bengerik citet akebaped haun mustipkeng kessi...gusa nuda nya apten Braha ? enpu masekam tapikun melgaptea messepandige Buha
# ----
# iter 500000, loss: 56.540220
# ----
#  Nippatk temangan broso kan
#
#
# Kacitan gading waling meruang ga sulat aket Andar😭 : (*New*)
# - Miss V*r)
#
# (9Lan yackan sersisinyat
#
# SIP...09- Sarkita fasat iapoiss (New )
# - Miss M*lt Dain, Seroh diara ga
# ----
# iter 510000, loss: 34.401582
# ----
#  an bah teripudak buan arU berinya nuak sima dongan", bihai Di mubinyan hand* ►
#
# Kandik janda ►
# Setok kunyu du + gakin dag tama dan misad ane berbur keluaya yaS2 8 samp stha tita juhj bentuk jalng njan
# ----
# iter 520000, loss: 30.724520
# ----
#   yaa pangh hu bauwa ya handih
# ngrote:
# RO:
#
#
# Fasuh (uid+an2 (Jan gur
#
# Prnyasak, huun jadi ane nakit l2
# nuk mex+.
# By mawv*
# - Miss Dianny
# - Miss Vi*d 10 suan dia inpang masud gaya.
# Yang penjialang lhema
# ----
# iter 530000, loss: 40.328716
# ----
#  Preraperbir ngediarn ke kumasan tha2 yg kempapen", rinyang ga gagri tita unau mamom ngrikensu yg akelan in denyay
# * Yhetah b yg unas
#
# Kee fudung pookbari keguas keq lahungk meberin deratan nejukin"
#
# M
# ----
# iter 540000, loss: 46.351718
